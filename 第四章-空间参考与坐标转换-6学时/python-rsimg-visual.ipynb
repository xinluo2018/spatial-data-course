# %% [markdown]
# ### matplotlib

# %% [markdown]
# 绘图基础

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 图像显示

# %%
img = np.arange(0,256,1).reshape(16,16)
fig, ax = plt.subplots(1,1)
ax.imshow(img)
